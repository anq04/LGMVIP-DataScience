# %% [markdown]
# # TASK 1: IRIS DATASET CLASSIFICATION

# %% [markdown]
# ### LetsGrowMore Virtual Internship Program May 2022

# %% [markdown]
# ### Data Science Intern - Amna Naseem

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
labels=['sepal_length','sepal_width','petal_length','petal_width','class']
# iris_dset=pd.read_csv(r'C:\Users\Computers way\Downloads\iris.csv',names=labels)

iris_dset=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',names=labels)
iris_dset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# iris_dset.shape
iris_dset.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
iris_dset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_dset['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
iris_dset['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
sns.countplot(iris_dset['class'])
plt.show()

# %%
iris_dset.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris_dset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.violinplot(y='class', x='sepal_length', data=iris_dset, inner='quartile')
plt.show()
sns.violinplot(y='class', x='sepal_width', data=iris_dset, inner='quartile')
plt.show()
sns.violinplot(y='class', x='petal_length', data=iris_dset, inner='quartile')
plt.show()
sns.violinplot(y='class', x='petal_width', data=iris_dset, inner='quartile')
plt.show()

# %%
sns.pairplot(iris_dset)

# %%
plt.figure(figsize=(16,10))
sns.heatmap(iris_dset.corr(),  annot=True, annot_kws={"size": 14})
sns.set_style('darkgrid')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Correlation between features")
plt.show()

# %%
x = iris_dset.drop(['class'], axis=1)
y = iris_dset['class']
print(f'x shape: {x.shape} | y shape: {y.shape} ')
# Out:
# x shape: (150, 4) | y shape: (150,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
model= []
model.append(LogisticRegression(max_iter=3000))
model.append(LinearDiscriminantAnalysis())
model.append(KNeighborsClassifier())
model.append(DecisionTreeClassifier())
model.append(GaussianNB())

for modl in model:
    m_fit=modl.fit(x_train,y_train)
    predict_y=m_fit.predict(x_test)
    accuracy=accuracy_score(y_test,predict_y)
    matrix=confusion_matrix(y_test,predict_y)
    report=classification_report(y_test,predict_y)
    print(str(m_fit)+'\nAccuracy:'+str(accuracy)+'\nConfusion Matrix:'+str(matrix)+'\nClassification Report:'+str(report))
# Out:
# LogisticRegression(max_iter=3000)
# Accuracy:0.9777777777777777
# Confusion Matrix:[[14  0  0]
#  [ 0 17  1]
#  [ 0  0 13]]
# Classification Report:                 precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      0.94      0.97        18
#  Iris-virginica       0.93      1.00      0.96        13
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# LinearDiscriminantAnalysis()
# Accuracy:1.0
# Confusion Matrix:[[14  0  0]
#  [ 0 18  0]
#  [ 0  0 13]]
# Classification Report:                 precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      1.00      1.00        18
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
# ...

# %% [markdown]
# Conclusion: Linear Discriminant Analysis has the highest accuracy
